# %%
import pandas as pd

# %%
df = pd.read_csv("/home/blade/Desktop/studia/research/labels(1).csv", sep="\t")
df
# Out:
# /tmp/ipykernel_2355597/746396783.py:1: DtypeWarning: Columns (4,5) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("/home/blade/Desktop/studia/research/labels(1).csv", sep="\t")
#                                    file  examination sequence  frame label  \
# 0        0001/samples/frames/000001.png            1  samples      1   NaN
# 1        0001/samples/frames/000001.png            1  samples      1   c20
# 2        0001/samples/frames/000002.png            1  samples      2   NaN
# 3        0001/samples/frames/000002.png            1  samples      2   c20
# 4        0001/samples/frames/000003.png            1  samples      3   NaN
# ...                                 ...          ...      ...    ...   ...
# 1540108   1135/seq_01/frames/055783.png         1135   seq_01  55783   NaN
# 1540109   1135/seq_01/frames/055784.png         1135   seq_01  55784   NaN
# 1540110   1135/seq_01/frames/055785.png         1135   seq_01  55785   NaN
# 1540111   1135/seq_01/frames/055786.png         1135   seq_01  55786   NaN
# 1540112   1135/seq_01/frames/055787.png         1135   seq_01  55787   NaN
#
#                                        mask
# 0                                       NaN
# 1        0001/samples/labels/000001_c20.png
# 2                                       NaN
# 3        0001/samples/labels/000002_c20.png
# 4                                       NaN
# ...                                     ...
# 1540108                                 NaN
# 1540109                                 NaN
# 1540110                                 NaN
# 1540111                                 NaN
# 1540112                                 NaN
#
# [1540113 rows x 6 columns]

# %%
df = df.drop(columns=["mask"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df = df.drop(columns=["mask"])
#       2 df = df.drop(columns = [df["label"] == "NaN"])
#       3 df
#
# File ~/ml/venv/lib/python3.12/site-packages/pandas/core/frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# File ~/ml/venv/lib/python3.12/site-packages/pandas/core/generic.py:4810, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4808 for axis, labels in axes.items():
#    4809     if labels is not None:
# -> 4810         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4812 if inplace:
#    4813     self._update_inplace(obj)
#
# File ~/ml/venv/lib/python3.12/site-packages/pandas/core/generic.py:4852, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4850         new_axis = axis.drop(labels, level=level, errors=errors)
#    4851     else:
# -> 4852         new_axis = axis.drop(labels, errors=errors)
#    4853     indexer = axis.get_indexer(new_axis)
#    4855 # Case for non-unique axis
#    4856 else:
#
# File ~/ml/venv/lib/python3.12/site-packages/pandas/core/indexes/base.py:7136, in Index.drop(self, labels, errors)
#    7134 if mask.any():
#    7135     if errors != "ignore":
# -> 7136         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7137     indexer = indexer[~mask]
#    7138 return self.delete(indexer)
#
# KeyError: "['mask'] not found in axis"

# %%
import numpy as np
df["label"] = df["label"].replace("NaN", np.nan)
df = df.dropna(subset=["label"])
df
# Out:
#                                    file  examination sequence  frame label
# 1        0001/samples/frames/000001.png            1  samples      1   c20
# 3        0001/samples/frames/000002.png            1  samples      2   c20
# 5        0001/samples/frames/000003.png            1  samples      3   c20
# 7        0001/samples/frames/000004.png            1  samples      4   c20
# 9        0001/samples/frames/000005.png            1  samples      5   c20
# ...                                 ...          ...      ...    ...   ...
# 1173106   1128/seq_01/frames/000157.png         1128   seq_01    157   c22
# 1173108   1128/seq_01/frames/000158.png         1128   seq_01    158   c22
# 1173110   1128/seq_01/frames/000159.png         1128   seq_01    159   c22
# 1173112   1128/seq_01/frames/000160.png         1128   seq_01    160   c22
# 1173114   1128/seq_01/frames/000161.png         1128   seq_01    161   c22
#
# [185413 rows x 5 columns]

# %%
ers_to_galar = {
                    # Ulcer
                    "c26": "ulcer", "c27": "ulcer",
                    "g18": "ulcer", "g19": "ulcer",
                    "g50": "ulcer", "g51": "ulcer", "g52": "ulcer",
                    "g10": "ulcer", "g33": "ulcer",
                    "g60": "ulcer",
                    # Polyp
                    "c22": "polyp", "g14": "polyp",
                    "g31": "polyp", "g45": "polyp",
                    "c23": "polyp",
                    # Active bleeding
                    "b01": "active_bleeding", "g19": "active_bleeding",
                    "g51": "active_bleeding", "g05": "active_bleeding",
                    "c02": "active_bleeding", "g15": "active_bleeding", 
                    "g46": "active_bleeding", "g62": "active_bleeding",
                    # Blood
                    "b": "blood", "b01": "blood",
                    # Erythema
                    "g22": "erythema", "g56": "erythema", "c19": "erythema",
                    "c24": "erythema", "c30": "erythema", "g32": "erythema",
                    "g59": "erythema",
                    # Erosion
                    "g20": "erosion", "g54": "erosion", "g07": "erosion",
                    "g21": "erosion",  # duodenopathy:hemorrhagic
                    "g55": "erosion", "g13": "erosion",
                    "g25": "erosion", "g29": "erosion",
                    "g58": "erosion", "g41": "erosion", "g43": "erosion",
                    # Angiectasia
                    "c01": "angiectasia", "g08": "angiectasia", "c28": "angiectasia",
                    # IBD (Crohn's / UC)
                    "c08": "IBD", "c09": "IBD", "c10": "IBD",
                    "c32": "IBD", "c33": "IBD", "c34": "IBD",
                    "g07": "IBD", "c03":"IBD", "c16": "IBD", "c11": "IBD", "c25": "IBD",
                    # Foreign body
                    "c14": "foreign_body", "g30": "foreign_body", "g42": "foreign_body","c20": "foreign_body", "g64": "foreign_body",
                    "g28": "foreign_body",  # esophageal_diverticulum
                    "g40": "foreign_body",  # gastric_diverticulum
                    "g37": "foreign_body",
                    # Esophagitis
                    "g23": "esophagitis", "g63": "esophagitis", "g67": "esophagitis", 
                    "g02": "esophagitis", "g04": "esophagitis",
                    # Varices
                    "g36": "varices", "g53": "varices", "c15": "varices", "g65": "varices",
                    # Hematin (no direct class, approximate)
                    "g47": "other",
                    "c07": "other",
                    "c12": "other",
                    "c21": "other",  # pneumatosis_coli
                    "g": "other",
                    "g01": "other", "g03": "other",
                    "g10": "other", "g12": "other",
                    "g24": "other",
                    "g27": "other",
                    "g57": "other",
                    "g61": "other",
                    "g66": "other", "g68": "other", "g69": "other",
                    # Celiac
                    "g06": "celiac",
                    # Cancer
                    "c05": "cancer", "g11": "cancer", "g26": "cancer",
                    "g39": "cancer", "c29": "cancer", "g44": "cancer",
                    "c06": "cancer", "c18": "cancer",
                    "g17": "cancer",
                    "g34": "cancer",
                    "g49": "cancer",
                    "c04": "cancer",
                    "c17": "cancer",
                    "c31": "cancer",
                    "g09": "cancer",
                    "g16": "cancer",
                    "g35": "cancer",
                    "g38": "cancer",
                    "g48": "cancer",
                    "g70": "cancer",

                    #healthy
                    "h01": "healthy",
                    "h02":"healthy",
                    "h03": "healthy",
                    "h04": "healthy",
                    "h05": "healthy",
                    "h06": "healthy",
                    "h07": "healthy",
                }

# %%
unified_classes = [
                "ulcer", "polyp", "active_bleeding", "blood",
                "erythema", "erosion", "angiectasia", "IBD",
                "foreign_body", "esophagitis", "varices", "hematin",
                "celiac", "cancer", "lymphangioectasis", "other"
            ]

# %%
df["label"] = df["label"].replace(ers_to_galar)
df
# Out:
# /tmp/ipykernel_2355597/2000259806.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["label"] = df["label"].replace(ers_to_galar)
#                                    file  examination sequence  frame  \
# 1        0001/samples/frames/000001.png            1  samples      1
# 3        0001/samples/frames/000002.png            1  samples      2
# 5        0001/samples/frames/000003.png            1  samples      3
# 7        0001/samples/frames/000004.png            1  samples      4
# 9        0001/samples/frames/000005.png            1  samples      5
# ...                                 ...          ...      ...    ...
# 1173106   1128/seq_01/frames/000157.png         1128   seq_01    157
# 1173108   1128/seq_01/frames/000158.png         1128   seq_01    158
# 1173110   1128/seq_01/frames/000159.png         1128   seq_01    159
# 1173112   1128/seq_01/frames/000160.png         1128   seq_01    160
# 1173114   1128/seq_01/frames/000161.png         1128   seq_01    161
#
#                 label
# 1        foreign_body
# 3        foreign_body
# 5        foreign_body
# 7        foreign_body
# 9        foreign_body
# ...               ...
# 1173106         polyp
# 1173108         polyp
# 1173110         polyp
# 1173112         polyp
# 1173114         polyp
#
# [185413 rows x 5 columns]

# %%
df["examination"].unique()
# Out:
# array([   1,    2,    3, ..., 1126, 1127, 1128], shape=(1114,))
