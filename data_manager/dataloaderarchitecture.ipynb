# %%
import json
from datetime import datetime

import torch
from torch.utils.data import DataLoader, random_split
from torch.utils.tensorboard import SummaryWriter
from torchvision import datasets, transforms


from sklearn.metrics import confusion_matrix

# %%
path1 = """/home/blade/ml/studia/zpb/61"""
path2 = """/home/blade/ml/studia/zpb/62"""
path3 = """/home/blade/ml/studia/zpb/63"""

# %%
from pathlib import Path
import pandas as pd

df = pd.read_csv("/home/blade/Desktop/studia/research/merged_galar.csv")
df = df.drop(columns=["Unnamed: 0"])
df.head(40)
# Out:
#     frame target_name  target  patient_id
# 0     100     neutral      15           1
# 1     105     neutral      15           1
# 2     110     neutral      15           1
# 3     115     neutral      15           1
# 4     120     neutral      15           1
# 5     125     neutral      15           1
# 6     130     neutral      15           1
# 7     135     neutral      15           1
# 8     140     neutral      15           1
# 9     145     neutral      15           1
# 10    150     neutral      15           1
# 11    155     neutral      15           1
# 12    160     neutral      15           1
# 13    165     neutral      15           1
# 14    170     neutral      15           1
# 15    175     neutral      15           1
# 16    180     neutral      15           1
# 17    185     neutral      15           1
# 18    190     neutral      15           1
# 19    195     neutral      15           1
# 20    200     neutral      15           1
# 21    205     neutral      15           1
# 22    210     neutral      15           1
# 23    215     neutral      15           1
# 24    220     neutral      15           1
# 25    225     neutral      15           1
# 26    230     neutral      15           1
# 27    235     neutral      15           1
# 28    240     neutral      15           1
# 29    245     neutral      15           1
# 30    250     neutral      15           1
# 31    255     neutral      15           1
# 32    260     neutral      15           1
# 33    265     neutral      15           1
# 34    270     neutral      15           1
# 35    275     neutral      15           1
# 36    280     neutral      15           1
# 37    285     neutral      15           1
# 38    290     neutral      15           1
# 39    295     neutral      15           1
